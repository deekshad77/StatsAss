# %%
import scipy as sp

# %%
dir(sp)
# Out:
# ['LowLevelCallable',
#  '__numpy_version__',
#  '__version__',
#  'cluster',
#  'fft',
#  'fftpack',
#  'integrate',
#  'interpolate',
#  'io',
#  'linalg',
#  'misc',
#  'ndimage',
#  'odr',
#  'optimize',
#  'show_config',
#  'signal',
#  'sparse',
#  'spatial',
#  'special',
#  'stats',
#  'test']

# %%
dir(sp.stats)
# Out:
# ['ConstantInputWarning',
#  'DegenerateDataWarning',
#  'FitError',
#  'NearConstantInputWarning',
#  'NumericalInverseHermite',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_axis_nan_policy',
#  '_biasedurn',
#  '_binned_statistic',
#  '_binomtest',
#  '_boost',
#  '_common',
#  '_constants',
#  '_continuous_distns',
#  '_crosstab',
#  '_discrete_distns',
#  '_distn_infrastructure',
#  '_distr_params',
#  '_entropy',
#  '_fit',
#  '_hypotests',
#  '_hypotests_pythran',
#  '_kde',
#  '_ksstats',
#  '_levy_stable',
#  '_mannwhitneyu',
#  '_morestats',
#  '_mstats_basic',
#  '_mstats_extras',
#  '_multivariate',
#  '_mvn',
#  '_page_trend_test',
#  '_qmc',
#  '_qmc_cy',
#  '_relative_risk',
#  '_resampling',
#  '_rvs_sampling',
#  '_sobol',
#  '_statlib',
#  '_stats',
#  '_stats_mstats_common',
#  '_stats_py',
#  '_tukeylambda_stats',
#  '_unuran',
#  '_variation',
# ...

# %%
import pandas as pd

# %%
dt=pd.read_csv("Q9_a.csv")

# %%
dt
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
skew1=sp.stats.skew(dt["speed"])
skew1
# Out:
# -0.11395477012828319

# %%
skew2=sp.stats.skew(dt["dist"])
skew2
# Out:
# 0.7824835173114966

# %%
kurt1=sp.stats.kurtosis(dt["speed"])
kurt1
# Out:
# -0.5771474239437371

# %%
kurt1=sp.stats.kurtosis(dt["dist"])
kurt1
# Out:
# 0.24801865717051808
